# %% [markdown]
# # 0. Import & Datensatz laden

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Titanic-Datensatz einlesen
df = pd.read_csv("data/titanic.csv")

df.head()
