# %% [markdown]
# # 0. Import & Datensatz laden

# %%
# %pip install pandas==2.2.2 seaborn==0.13.2 numpy==2.0.2

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Penguins-Dataset laden
def load_penguins():
    try:
        return sns.load_dataset("penguins")
    except Exception:
        path = "data/penguins.csv"
        return pd.read_csv(path)

df = load_penguins()

df.head()

# %% [markdown]
# # 1. Aufgabe Berechnung statistischer Lagemaße
# Im Weiteren sollen diverse statistische Werte berechnet werden.
# ## 1.1 Mean

# %%
mean_values = df_num.
print("Mean:\n", mean_values)

# %% [markdown]
# ## 1.2 Median

# %%
median_values = df_num.
print("\nMedian:\n", median_values)

# %% [markdown]
# ## 1.3 Varianz

# %%
variance_values = df_num.
print("\nVarianz:\n", variance_values)

# %% [markdown]
# ## 1.4 Standardabweichung

# %%
std_values = df_num.
print("\nStandardabweichung:\n", std_values)

# %% [markdown]
# ## 1.5 Interquartilsabstand

# %%
iqr_values = df_num.quantile(0.75) - df_num.
print("\nIQR:\n", iqr_values)

# %% [markdown]
# ## 2. Berechnung Korrelationen
# In diesem Abschnitt sollen Korrelationen zwischen den Datensätzen berechnet werden.

# %% [markdown]
# ## 2.1 Pearson-Korrelation

# %%
pearson_corr = df_num.corr(method="")
print("\nPearson-Korrelation:\n", pearson_corr)

# %% [markdown]
# ## 2.2 Spearmen-Korrelation

# %%
spearman_corr = df_num.
print("\nSpearman-Korrelation:\n", spearman_corr)

# %% [markdown]
# # 3. Grafische Darstellung der Ergebnisse

# %%
# --- Heatmap der Pearson-Korrelation ---
plt.figure(figsize=(8, 6))
sns.heatmap(pearson_corr, annot=True, cmap="viridis")
plt.title("Heatmap der Pearson-Korrelation")
plt.show()


# --- Scatterplot ---
### TODO ###
x_var =
y_var =

plt.figure(figsize=(6, 5))
sns.scatterplot(data=df, x=x_var, y=y_var)
plt.title(f"Scatterplot: {x_var} vs. {y_var}")
plt.show()
